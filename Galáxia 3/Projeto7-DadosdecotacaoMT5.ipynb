# %% [markdown]
# # Projeto 7 - Dados de cotação no MT5

# %%
#!pip install MetaTrader5
#!pip install --upgrade MetaTrader5
# Out:
# Collecting numpy==1.14.5
#   Using cached numpy-1.14.5.zip (4.9 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3
#   Running setup.py install for numpy: started
#   Running setup.py install for numpy: finished with status 'error'
#   Rolling back uninstall of numpy
#   Moving to c:\users\ronal\anaconda3\lib\site-packages\numpy-1.26.3-cp39-cp39-win_amd64.whl
#    from C:\Users\ronal\AppData\Local\Temp\pip-uninstall-hwyfk1i3\numpy-1.26.3-cp39-cp39-win_amd64.whl
#   Moving to c:\users\ronal\anaconda3\lib\site-packages\numpy-1.26.3.dist-info\
#    from C:\Users\ronal\anaconda3\Lib\site-packages\~umpy-1.26.3.dist-info
#   Moving to c:\users\ronal\anaconda3\lib\site-packages\numpy.libs\
#    from C:\Users\ronal\anaconda3\Lib\site-packages\~umpy.libs
#   Moving to c:\users\ronal\anaconda3\lib\site-packages\numpy\
#    from C:\Users\ronal\anaconda3\Lib\site-packages\~umpy
#   Moving to c:\users\ronal\anaconda3\scripts\f2py.exe
#    from C:\Users\ronal\AppData\Local\Temp\pip-uninstall-110er2_l\f2py.exe
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [264 lines of output]
#   Running from numpy source directory.
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\misc_util.py:464: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion' nÆo ‚ reconhecido como um comando interno
#   ou externo, um programa oper vel ou um arquivo em lotes.
#   'svnversion' nÆo ‚ reconhecido como um comando interno
#   ou externo, um programa oper vel ou um arquivo em lotes.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   F2PY Version 2
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\ronal\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:262: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build\src.win-amd64-3.9
#   creating build\src.win-amd64-3.9\numpy
#   creating build\src.win-amd64-3.9\numpy\distutils
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
#   error: subprocess-exited-with-error
#
#   python setup.py clean did not run successfully.
#   exit code: 1
#
#   [10 lines of output]
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
#   error: subprocess-exited-with-error
#
#   Running setup.py install for numpy did not run successfully.
#   exit code: 1
#
#   [269 lines of output]
#   Running from numpy source directory.
#
#   Note: if you need reliable uninstall behavior, then install
#   with pip instead of using `setup.py install`:
#
#     - `pip install .`       (from a git repo or downloaded source
#                              release)
#     - `pip install numpy`   (last NumPy release on PyPi)
#
#
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion' nÆo ‚ reconhecido como um comando interno
#   ou externo, um programa oper vel ou um arquivo em lotes.
#   'svnversion' nÆo ‚ reconhecido como um comando interno
#   ou externo, um programa oper vel ou um arquivo em lotes.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   F2PY Version 2
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\ronal\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\ronal\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\ronal\\anaconda3\\lib', 'C:\\', 'C:\\Users\\ronal\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\ronal\AppData\Local\Temp\pip-install-owqsjzk2\numpy_9eeeb5ae0ecd4d50acabf724ac226e18\numpy\distutils\system_info.py:624: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\ronal\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:262: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running install
#   C:\Users\ronal\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import pandas as pd
import MetaTrader5 as mt5
import pandas as pd
import datetime
import pytz

# %% [markdown]
# ## Documentação
#
# https://www.mql5.com/en/docs/python_metatrader5

# %%
mt5.initialize()
# Out:
# True

# %%
mt5.symbol_select('ABEV3')
# Out:
# True

# %% [markdown]
# ### Selecionando todas as ações

# %%
simbolos = mt5.symbols_get()
simbolos
# Out:
# (SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1747260900, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP330', name='DAPK25', page='', path='BMF\\DAPK25'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2062789800, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP2L0', name='DAPK35', page='', path='BMF\\DAPK35'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2378240100, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP3B9', name='DAPK45', page='', path='BMF\\DAPK45'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2693945700, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP3D5', name='DAPK55', page='', path='BMF\\DAPK55'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1723669859, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP1F4', name='DAPQ24', page='', path='BMF\\DAPQ24'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1786741859, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP1L2', name='DAPQ26', page='', path='BMF\\DAPQ26'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1849900259, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP280', name='DAPQ28', page='', path='BMF\\DAPQ28'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1912972259, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP1E7', name='DAPQ30', page='', path='BMF\\DAPQ30'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2228595300, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP3A1', name='DAPQ40', page='', path='BMF\\DAPQ40'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2543955300, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=2.5e-06, trade_tick_value_profit=2.5e-06, trade_tick_value_loss=2.5e-06, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=3000.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='CUPOM DE IPCA', exchange='BVMF', formula='', isin='BRBMEFDAP3C7', name='DAPQ50', page='', path='BMF\\DAPQ50'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1735593059, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO0U4', name='DCOF25', page='', path='BMF\\DCOF25'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1767129059, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO156', name='DCOF26', page='', path='BMF\\DCOF26'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1798665059, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO1S6', name='DCOF27', page='', path='BMF\\DCOF27'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1830201059, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO1P2', name='DCOF28', page='', path='BMF\\DCOF28'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1861650659, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO1R8', name='DCOF29', page='', path='BMF\\DCOF29'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1893186659, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO1Q0', name='DCOF30', page='', path='BMF\\DCOF30'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1924899300, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO313', name='DCOF31', page='', path='BMF\\DCOF31'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1988057700, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO3D4', name='DCOF33', page='', path='BMF\\DCOF33'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2050956900, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO3C6', name='DCOF35', page='', path='BMF\\DCOF35'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=2082492900, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO3O1', name='DCOF36', page='', path='BMF\\DCOF36'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1711664100, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO354', name='DCOJ24', page='', path='BMF\\DCOJ24'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1743459300, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO3G7', name='DCOJ25', page='', path='BMF\\DCOJ25'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1774995300, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO3R4', name='DCOJ26', page='', path='BMF\\DCOJ26'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1719609059, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO2G9', name='DCON24', page='', path='BMF\\DCON24'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1751317800, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO2U0', name='DCON25', page='', path='BMF\\DCON25'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=33, trade_mode=4, start_time=0, expiration_time=1782853800, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=2, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.0005, trade_tick_value_profit=0.0005, trade_tick_value_loss=0.0005, trade_tick_size=0.001, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=300.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='COMPROM.CAMBIAL', exchange='BVMF', formula='', isin='BRBMEFDCO2V8', name='DCON26', page='', path='BMF\\DCON26'),
# ...
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=100.0, volume_max=2154954.0, volume_step=100.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='LITEL       ON      MB', exchange='BVMF', formula='', isin='BRLTELACNOR1', name='LTEL3B', page='', path='BOVESPA\\A VISTA\\LTEL3B'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=100.0, volume_max=1967131.0, volume_step=100.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='LITELA      ON      MB', exchange='BVMF', formula='', isin='BRLTLAACNOR9', name='LTLA3B', page='', path='BOVESPA\\A VISTA\\LTLA3B'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=11307.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='FII LUGGO   CI', exchange='BVMF', formula='', isin='BRLUGGCTF007', name='LUGG11', page='', path='BOVESPA\\A VISTA\\LUGG11'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=1761091199, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=100.0, volume_max=34045.0, volume_step=100.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='LUPATECH    BNS ORD NM', exchange='BVMF', formula='', isin='BRLUPAN01OR2', name='LUPA11', page='', path='BOVESPA\\A VISTA\\LUPA11'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=100.0, volume_max=410398.0, volume_step=100.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='LUPATECH    ON      NM', exchange='BVMF', formula='', isin='BRLUPAACNOR8', name='LUPA3', page='', path='BOVESPA\\A VISTA\\LUPA3'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=100.0, volume_max=91920.0, volume_step=100.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='TREVISA     ON', exchange='BVMF', formula='', isin='BRLUXMACNOR7', name='LUXM3', page='', path='BOVESPA\\A VISTA\\LUXM3'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=100.0, volume_max=115920.0, volume_step=100.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='TREVISA     PN', exchange='BVMF', formula='', isin='BRLUXMACNPR4', name='LUXM4', page='', path='BOVESPA\\A VISTA\\LUXM4'),
#  SymbolInfo(custom=False, chart_mode=1, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=253402300799, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=142437.0, volume_step=1.0, volume_limit=0.0, swap_long=0.0, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=0.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='BRL', currency_profit='BRL', currency_margin='BRL', bank='', description='FII VBI LOG CI', exchange='BVMF', formula='', isin='BRLVBICTF002', name='LVBI11', page='', path='BOVESPA\\A VISTA\\LVBI11'),
#  ...)

# %%
tickers = [simbolo.name for simbolo in simbolos]
tickers = sorted(tickers, reverse=True)

tickers
# Out:
# ['ZIFI11',
#  'ZAVI11',
#  'ZARM24',
#  'ZARK24',
#  'ZARJ24',
#  'ZARH24',
#  'ZARG24',
#  'ZAMP3R',
#  'ZAMP3Q',
#  'ZAMP3M',
#  'ZAMP3',
#  'Z2SC34R',
#  'Z2SC34Q',
#  'Z2SC34M',
#  'Z2SC34',
#  'Z2LL35',
#  'Z2LL34',
#  'Z2IT34',
#  'Z2DV34',
#  'Z1TS34R',
#  'Z1TS34Q',
#  'Z1TS34M',
#  'Z1TS34',
#  'Z1TO34',
#  'Z1OM34R',
#  'Z1OM34Q',
#  'Z1OM34M',
#  'Z1OM34',
#  'Z1IO34',
#  'Z1BR34',
#  'Z1BH34',
#  'YUMR34',
#  'YUFI11',
#  'YDUQ3R',
#  'YDUQ3Q',
#  'YDUQ3M',
#  'YDUQ3',
#  'YDRO11',
#  'YBRA4',
#  'YBRA3',
#  'Y2PF34',
#  'XRXB34',
#  'XRAY34',
#  'XPSF11',
#  'XPPR11',
#  'XPML11',
#  'XPLG11',
#  'XPIN11',
#  'XPIE11',
#  'XPID11',
#  'XPCM11',
#  'XPCI11',
#  'XPCA11',
#  'XPBR31R',
#  'XPBR31Q',
#  'XPBR31M',
#  'XPBR31',
#  'XINA11',
#  'XFIX11',
#  'XFIX',
#  'XBOV11',
#  'XBOV',
#  'X1YL34',
#  'X1EL34',
#  'WUNI34R',
#  'WUNI34Q',
#  'WUNI34M',
#  'WUNI34',
#  'WTSP11',
#  'WSPM24',
#  'WSPH24',
#  'WSEC11',
#  'WRLD11',
#  'WPLZ11',
#  'WLMM4R',
#  'WLMM4Q',
#  'WLMM4M',
#  'WLMM4',
#  'WLMM3',
#  'WIZC3R',
#  'WIZC3Q',
#  'WIZC3M',
#  'WIZC3',
#  'WINZ25',
#  'WINZ24',
#  'WINV25',
#  'WINV24',
#  'WINQ25',
#  'WINQ24',
#  'WINM25',
#  'WINM24',
#  'WINJ25',
#  'WINJ24',
#  'WING26',
#  'WING25',
#  'WING24',
#  'WIN@N',
#  'WIN@D',
#  'WIN@',
#  'WIN$N',
#  'WIN$D',
#  'WIN$',
#  'WHRL4R',
#  'WHRL4Q',
#  'WHRL4M',
#  'WHRL4',
#  'WHRL3R',
#  'WHRL3Q',
#  'WHRL3M',
#  'WHRL3',
#  'WHGR11',
#  'WGBA34R',
#  'WGBA34Q',
#  'WGBA34M',
#  'WGBA34',
#  'WFCO34R',
#  'WFCO34Q',
#  'WFCO34M',
#  'WFCO34',
#  'WEUH24',
#  'WEUG24',
#  'WEST3R',
#  'WEST3Q',
#  'WEST3M',
#  'WEST3',
#  'WEGE3R',
#  'WEGE3Q',
#  'WEGE3M',
#  'WEGE3',
#  'WEB311',
#  'WDOV24',
#  'WDON24',
#  'WDOM24',
#  'WDOK24',
#  'WDOJ24',
#  'WDOH24',
#  'WDOG24',
#  'WDOF25',
#  'WDO@N',
#  'WDO@D',
#  'WDO@',
#  'WDO$N',
#  'WDO$D',
#  'WDO$',
#  'WATC34',
#  'WALM34R',
#  'WALM34Q',
#  'WALM34M',
#  'WALM34',
#  'WABC34R',
#  'WABC34Q',
#  'WABC34M',
#  'WABC34',
#  'W2YF34R',
#  'W2YF34Q',
#  'W2YF34M',
#  'W2YF34',
#  'W2ST34',
#  'W2OL34',
#  'W2EX34',
#  'W1YN34',
#  'W1YC34',
#  'W1SO34',
#  'W1RB34',
#  'W1PP34',
#  'W1MG34R',
#  'W1MG34Q',
#  'W1MG34M',
#  'W1MG34',
#  'W1MC34R',
#  'W1MC34Q',
#  'W1MC34M',
#  'W1MC34',
#  'W1MB34',
#  'W1LT34',
#  'W1IX34R',
#  'W1IX34Q',
#  'W1IX34M',
#  'W1IX34',
#  'W1HR34',
#  'W1EL34R',
#  'W1EL34Q',
#  'W1EL34M',
#  'W1EL34',
#  'W1EC34',
#  'W1DC34',
#  'W1DA34',
#  'W1BO34R',
#  'W1BO34Q',
#  'W1BO34M',
#  'W1BO34',
#  'W1BD34R',
#  'W1BD34Q',
#  'W1BD34M',
#  'W1BD34',
#  'W1AB34R',
#  'W1AB34Q',
#  'W1AB34M',
#  'W1AB34',
#  'VXXV11',
#  'VVRI11',
#  'VVEO3R',
#  'VVEO3Q',
#  'VVEO3M',
#  'VVEO3',
#  'VVCR11',
#  'VVCO11',
#  'VULC3R',
#  'VULC3Q',
#  'VULC3M',
#  'VULC3',
#  'VTLT11',
#  'VSTE3R',
#  'VSTE3Q',
#  'VSTE3M',
#  'VSTE3',
#  'VSTE1',
#  'VSPT4',
#  'VSPT3',
#  'VSLH11',
#  'VSHO11',
#  'VRTX34R',
#  'VRTX34Q',
#  'VRTX34M',
#  'VRTX34',
#  'VRTM11',
#  'VRTA11',
#  'VRSN34',
#  'VPSI11',
#  'VOTS11',
#  'VLYB34',
#  'VLOE34R',
#  'VLOE34Q',
#  'VLOE34M',
#  'VLOE34',
#  'VLJS11',
#  'VLID3R',
#  'VLID3Q',
#  'VLID3M',
#  'VLID3',
#  'VIVT3R',
#  'VIVT3Q',
#  'VIVT3M',
#  'VIVT3',
#  'VIVR3R',
#  'VIVR3Q',
#  'VIVR3M',
#  'VIVR3',
#  'VIVR1',
#  'VIVA3R',
#  'VIVA3Q',
#  'VIVA3M',
#  'VIVA3',
#  'VIUR11',
#  'VITT3R',
#  'VITT3Q',
#  'VITT3M',
#  'VITT3',
#  'VISC11',
#  'VISA34R',
#  'VISA34Q',
#  'VISA34M',
#  'VISA34',
#  'VINO11',
#  'VILG11',
#  'VIGT11',
#  'VIFI11',
#  'VIDS11',
#  'VGIR11',
#  'VGIP11',
#  'VGII11',
#  'VGIA11',
#  'VGHF11',
#  'VFCO34R',
#  'VFCO34Q',
#  'VFCO34M',
#  'VFCO34',
#  'VERZ34R',
#  'VERZ34Q',
#  'VERZ34M',
#  'VERZ34',
#  'VERE11',
#  'VCRR11',
#  'VCRI11',
#  'VCRA11',
#  'VCJR11',
#  'VBBR3R',
#  'VBBR3Q',
#  'VBBR3M',
#  'VBBR3',
#  'VAMO3R',
#  'VAMO3Q',
#  'VAMO3M',
#  'VAMO3',
#  'VALEOH24',
#  'VALEOG24',
#  'VALE3R',
#  'VALE3Q',
#  'VALE3M',
#  'VALE3',
#  'V2TX34',
#  'V2RN34',
#  'V2ME34R',
#  'V2ME34Q',
#  'V2ME34M',
#  'V2ME34',
#  'V2EE34',
#  'V1TA34',
#  'V1RS34',
#  'V1OD34R',
#  'V1OD34Q',
#  'V1OD34M',
#  'V1OD34',
#  'V1NO34R',
#  'V1NO34Q',
#  'V1NO34M',
#  'V1NO34',
#  'V1MC34',
#  'V1IP34R',
#  'V1IP34Q',
#  'V1IP34M',
#  'V1IP34',
#  'UTIL11',
#  'UTIL',
#  'UTEC11',
#  'USTK11',
#  'USSX34R',
#  'USSX34Q',
#  'USSX34M',
#  'USSX34',
#  'USIMAH24',
#  'USIMAG24',
#  'USIM6',
#  'USIM5R',
#  'USIM5Q',
#  'USIM5M',
#  'USIM5',
#  'USIM3R',
#  'USIM3Q',
#  'USIM3M',
#  'USIM3',
#  'USDB11',
#  'USBC34R',
#  'USBC34Q',
#  'USBC34M',
#  'USBC34',
#  'USAL11',
#  'URPR11',
#  'URET11',
#  'UPSS34R',
#  'UPSS34Q',
#  'UPSS34M',
#  'UPSS34',
#  'UPKP3',
#  'UPAC34R',
#  'UPAC34Q',
#  'UPAC34M',
#  'UPAC34',
#  'UNIP6R',
#  'UNIP6Q',
#  'UNIP6M',
#  'UNIP6',
#  'UNIP5R',
#  'UNIP5Q',
#  'UNIP5M',
#  'UNIP5',
#  'UNIP3R',
#  'UNIP3Q',
#  'UNIP3M',
#  'UNIP3',
#  'UNHH34R',
#  'UNHH34Q',
#  'UNHH34M',
#  'UNHH34',
#  'UNAG12',
#  'UNAG11',
#  'ULEV34R',
#  'ULEV34Q',
#  'ULEV34M',
#  'ULEV34',
#  'UGPA3R',
#  'UGPA3Q',
#  'UGPA3M',
#  'UGPA3',
#  'UCAS3R',
#  'UCAS3Q',
#  'UCAS3M',
#  'UCAS3',
#  'UBSG34R',
#  'UBSG34Q',
#  'UBSG34M',
#  'UBSG34',
#  'U2TH34',
#  'U2ST34R',
#  'U2ST34Q',
#  'U2ST34M',
#  'U2ST34',
#  'U2PW34R',
#  'U2PW34Q',
#  'U2PW34M',
#  'U2PW34',
#  'U2PS34R',
#  'U2PS34Q',
#  'U2PS34M',
#  'U2PS34',
#  'U2NF34',
#  'U1RI34R',
#  'U1RI34Q',
#  'U1RI34M',
#  'U1RI34',
#  'U1NM34R',
#  'U1NM34Q',
#  'U1NM34M',
#  'U1NM34',
#  'U1LT34R',
#  'U1LT34Q',
#  'U1LT34M',
#  'U1LT34',
#  'U1HS34',
#  'U1DR34',
#  'U1BE34R',
#  'U1BE34Q',
#  'U1BE34M',
#  'U1BE34',
#  'U1AL34R',
#  'U1AL34Q',
#  'U1AL34M',
#  'U1AL34',
#  'U1AI34R',
#  'U1AI34Q',
#  'U1AI34M',
#  'U1AI34',
#  'TXSA34R',
#  'TXSA34Q',
#  'TXSA34M',
#  'TXSA34',
#  'TXRX4R',
#  'TXRX4Q',
#  'TXRX4M',
#  'TXRX4',
#  'TXRX3',
#  'TVRI11',
#  'TUPY3R',
#  'TUPY3Q',
#  'TUPY3M',
#  'TUPY3',
#  'TTEN3R',
#  'TTEN3Q',
#  'TTEN3M',
#  'TTEN3',
#  'TSNF34R',
#  'TSNF34Q',
#  'TSNF34M',
#  'TSNF34',
#  'TSNC11',
#  'TSMC34R',
#  'TSMC34Q',
#  'TSMC34M',
#  'TSMC34',
#  'TSLA34R',
#  'TSLA34Q',
#  'TSLA34M',
#  'TSLA34',
#  'TSER11',
#  'TRYM24',
#  'TRYK24',
#  'TRYJ24',
#  'TRYH24',
#  'TRYG24',
#  'TRXF11',
#  'TRXB11',
#  'TRVC34R',
#  'TRVC34Q',
#  'TRVC34M',
#  'TRVC34',
#  'TRPL4R',
#  'TRPL4Q',
#  'TRPL4M',
#  'TRPL4',
#  'TRPL3R',
#  'TRPL3Q',
#  'TRPL3M',
#  'TRPL3',
#  'TRNT11',
#  'TRIS3R',
#  'TRIS3Q',
#  'TRIS3M',
#  'TRIS3',
#  'TRIG11',
#  'TRIG',
#  'TRBL11',
#  'TRAD3R',
#  'TRAD3Q',
#  'TRAD3M',
#  'TRAD3',
#  'TPRY34',
#  'TPIS3R',
#  'TPIS3Q',
#  'TPIS3M',
#  'TPIS3',
#  'TOTS3R',
#  'TOTS3Q',
#  'TOTS3M',
#  'TOTS3',
#  'TORD11',
#  'TMPS11',
#  'TMOS34R',
#  'TMOS34Q',
#  'TMOS34M',
#  'TMOS34',
#  'TMCO34R',
#  'TMCO34Q',
#  'TMCO34M',
#  'TMCO34',
#  'TLNC34R',
#  'TLNC34Q',
#  'TLNC34M',
#  'TLNC34',
#  'TKNO4',
#  'TKNO3',
#  'TJXC34R',
#  'TJXC34Q',
#  'TJXC34M',
#  'TJXC34',
#  'TJKB11',
#  'TIMS3R',
#  'TIMS3Q',
#  'TIMS3M',
#  'TIMS3',
#  'THRE34',
#  'THGI34',
#  'TGTB34R',
#  'TGTB34Q',
#  'TGTB34M',
#  'TGTB34',
#  'TGMA3R',
#  'TGMA3Q',
#  'TGMA3M',
#  'TGMA3',
#  'TGAR11',
#  'TFIX',
#  'TFCO4R',
#  'TFCO4Q',
#  'TFCO4M',
#  'TFCO4',
#  'TF9Z99',
#  'TF9Z98',
#  'TF9Z97',
#  'TF995',
#  'TF994',
#  'TF993',
#  'TF901',
#  'TF900',
#  'TF8Z99',
#  'TF8Z98',
#  'TF8Z97',
#  'TF7Z99',
#  'TF7Z98',
#  'TF7Z97',
#  'TF7Z90',
#  'TF729',
#  'TF728',
#  'TF724',
#  'TF723',
#  'TF714',
#  'TF713',
#  'TF704',
#  'TF703',
#  'TF6Z99',
#  'TF6Z98',
#  'TF6Z97',
#  'TF694',
#  'TF693',
#  'TF689',
#  'TF688',
#  'TF685',
#  'TF682',
#  'TF681',
#  'TF679',
#  'TF675',
#  'TF669',
#  'TF668',
#  'TF665',
#  'TF655',
#  'TF645',
#  'TF644',
#  'TF643',
#  'TF625',
#  'TF624',
#  'TF623',
#  'TF604',
#  'TF603',
#  'TF5Z99',
#  'TF5Z98',
#  'TF5Z97',
#  'TF5Z90',
#  'TF595',
#  'TF594',
#  'TF593',
#  'TF589',
#  'TF585',
#  'TF584',
#  'TF583R',
#  'TF583',
#  'TF575',
#  'TF574',
#  'TF573',
#  'TF569',
#  'TF565',
#  'TF564',
#  'TF563',
#  'TF555',
#  'TF554',
#  'TF553',
#  'TF549',
#  'TF545',
#  'TF544',
#  'TF543',
#  'TF535',
#  'TF534',
#  'TF533',
#  'TF529',
#  'TF525',
#  'TF524',
#  'TF523',
#  'TF519',
#  'TF518',
#  'TF515',
#  'TF514',
#  'TF513',
#  'TF505',
#  'TF504',
#  'TF503',
#  'TF4Z99',
#  'TF4Z98',
#  'TF4Z97',
#  'TF4Z90',
#  'TF495',
#  'TF494',
#  'TF493',
#  'TF485',
#  'TF484',
#  'TF483',
#  'TF475',
#  'TF474',
#  'TF473',
#  'TF3Z99',
#  'TF3Z98',
#  'TF3Z97',
#  'TF2Z99',
#  'TF2Z98',
#  'TF2Z97',
#  'TF1Z99',
#  'TF1Z98',
#  'TF1Z97',
#  'TF1Z90',
#  'TF11Z99',
#  'TF0Z99',
#  'TF0Z98',
#  'TF0Z97',
#  'TF0Z90',
#  'TEXA34R',
#  'TEXA34Q',
#  'TEXA34M',
#  'TEXA34',
#  'TEPP11',
#  'TEND3R',
#  'TEND3Q',
#  'TEND3M',
#  'TEND3',
#  'TELB4R',
#  'TELB4Q',
#  'TELB4M',
#  'TELB4',
#  'TELB3R',
#  'TELB3Q',
#  'TELB3M',
#  'TELB3',
#  'TEKA4R',
#  'TEKA4Q',
#  'TEKA4M',
#  'TEKA4',
#  'TEKA3',
#  'TEGA3',
#  'TECN3R',
#  'TECN3Q',
#  'TECN3M',
#  'TECN3',
#  'TECK11',
#  'TECB11',
#  'TECB',
#  'TCSA3R',
#  'TCSA3Q',
#  'TCSA3M',
#  'TCSA3',
#  'TCPF11',
#  'TCIN12',
#  'TCIN11',
#  'TCCO34',
#  'TAXA99L',
#  'TAXA99',
#  'TAXA98L',
#  'TAXA98',
#  'TAXA97L',
#  'TAXA97',
#  'TAXA96L',
#  'TAXA96',
#  'TAXA95L',
#  'TAXA95',
#  'TAXA94L',
#  'TAXA94',
#  'TAXA93L',
#  'TAXA93',
#  'TAXA92L',
#  'TAXA92',
#  'TAXA91L',
#  'TAXA91',
#  'TAXA90L',
#  'TAXA90',
#  'TAXA89L',
#  'TAXA89',
#  'TAXA88L',
#  'TAXA88',
#  'TAXA87L',
#  'TAXA87',
#  'TAXA86L',
#  'TAXA86',
#  'TAXA85L',
#  'TAXA85',
#  'TAXA84L',
#  'TAXA84',
#  'TAXA83L',
#  'TAXA83',
#  'TAXA82L',
#  'TAXA82',
#  'TAXA81L',
#  'TAXA81',
#  'TAXA80L',
#  'TAXA80',
#  'TAXA79L',
#  'TAXA79',
#  'TAXA78L',
#  'TAXA78',
#  'TAXA77L',
#  'TAXA77',
#  'TAXA76L',
#  'TAXA76',
#  'TAXA75L',
#  'TAXA75',
#  'TAXA74L',
#  'TAXA74',
#  'TAXA73L',
#  'TAXA73',
#  'TAXA72L',
#  'TAXA72',
#  'TAXA71L',
#  'TAXA71',
#  'TAXA70L',
#  'TAXA70',
#  'TAXA69L',
#  'TAXA69',
#  'TAXA68L',
#  'TAXA68',
#  'TAXA67L',
#  'TAXA67',
#  'TAXA66L',
#  'TAXA66',
#  'TAXA65L',
#  'TAXA65',
#  'TAXA64L',
#  'TAXA64',
#  'TAXA63L',
#  'TAXA63',
#  'TAXA62L',
#  'TAXA62',
#  'TAXA61L',
#  'TAXA61',
#  'TAXA60L',
#  'TAXA60',
#  'TAXA59L',
#  'TAXA59',
#  'TAXA58L',
#  'TAXA58',
#  'TAXA57L',
#  'TAXA57',
#  'TAXA56L',
#  'TAXA56',
#  'TAXA55L',
#  'TAXA55',
#  'TAXA54L',
#  'TAXA54',
#  'TAXA53L',
#  'TAXA53',
#  'TAXA52L',
#  'TAXA52',
#  'TAXA51L',
#  'TAXA51',
#  'TAXA50L',
#  'TAXA50',
#  'TAXA49L',
#  'TAXA49',
#  'TAXA48L',
#  'TAXA48',
#  'TAXA47L',
#  'TAXA47',
#  'TAXA46L',
#  'TAXA46',
#  'TAXA45L',
#  'TAXA45',
#  'TAXA44L',
#  'TAXA44',
#  'TAXA43L',
#  'TAXA43',
#  'TAXA42L',
#  'TAXA42',
#  'TAXA41L',
#  'TAXA41',
#  'TAXA40L',
#  'TAXA40',
#  'TAXA39L',
#  'TAXA39',
#  'TAXA38L',
#  'TAXA38',
#  'TAXA37L',
#  'TAXA37',
#  'TAXA36L',
#  'TAXA365',
#  'TAXA364',
#  'TAXA363',
#  'TAXA362',
#  'TAXA361',
#  'TAXA360',
#  'TAXA36',
#  'TAXA35L',
#  'TAXA359',
#  'TAXA358',
#  'TAXA357',
#  'TAXA356',
#  'TAXA355',
#  'TAXA354',
#  'TAXA353',
#  'TAXA352',
#  'TAXA351',
#  'TAXA350',
#  'TAXA35',
#  'TAXA34L',
#  'TAXA349',
#  'TAXA348',
#  'TAXA347',
#  'TAXA346',
#  'TAXA345',
#  'TAXA344',
#  'TAXA343',
#  'TAXA342',
#  'TAXA341',
#  'TAXA340',
#  'TAXA34',
#  'TAXA33L',
#  'TAXA339',
#  'TAXA338',
#  'TAXA337',
#  'TAXA336',
#  'TAXA335',
#  'TAXA334',
#  'TAXA333',
#  'TAXA332',
#  'TAXA331',
#  'TAXA330',
#  'TAXA33',
#  'TAXA32L',
#  'TAXA329',
#  'TAXA328',
#  'TAXA327',
#  'TAXA326',
#  'TAXA325',
#  'TAXA324',
#  'TAXA323',
#  'TAXA322',
#  'TAXA321',
#  'TAXA320',
#  'TAXA32',
#  'TAXA31L',
#  'TAXA319',
#  'TAXA318',
#  'TAXA317',
#  'TAXA316',
#  'TAXA315',
#  'TAXA314',
#  'TAXA313',
#  'TAXA312',
#  'TAXA311',
#  'TAXA310',
#  'TAXA31',
#  'TAXA30L',
#  'TAXA309',
#  'TAXA308',
#  'TAXA307',
#  'TAXA306',
#  'TAXA305',
#  'TAXA304',
#  'TAXA303',
#  'TAXA302',
#  'TAXA301',
#  'TAXA300',
#  'TAXA30',
#  'TAXA29L',
#  'TAXA299',
#  'TAXA298',
#  'TAXA297',
#  'TAXA296',
#  'TAXA295',
#  'TAXA294',
#  'TAXA293',
#  'TAXA292',
#  'TAXA291',
#  'TAXA290',
#  'TAXA29',
#  'TAXA28L',
#  'TAXA289',
#  'TAXA288',
#  'TAXA287',
#  'TAXA286',
#  'TAXA285',
#  'TAXA284',
#  'TAXA283',
#  'TAXA282',
#  'TAXA281',
#  'TAXA280',
#  'TAXA28',
#  'TAXA27L',
#  'TAXA279',
#  'TAXA278',
#  'TAXA277',
#  'TAXA276',
#  'TAXA275',
#  'TAXA274',
#  'TAXA273',
#  'TAXA272',
#  'TAXA271',
#  'TAXA270',
#  'TAXA27',
#  'TAXA26L',
#  'TAXA269',
#  'TAXA268',
#  'TAXA267',
#  'TAXA266',
#  'TAXA265',
#  'TAXA264',
#  'TAXA263',
#  'TAXA262',
#  'TAXA261',
#  'TAXA260',
#  'TAXA26',
#  'TAXA25L',
#  'TAXA259',
#  'TAXA258',
#  'TAXA257',
#  'TAXA256',
#  'TAXA255',
#  'TAXA254',
#  'TAXA253',
#  'TAXA252',
#  'TAXA251',
#  'TAXA250',
#  'TAXA25',
#  'TAXA24L',
#  'TAXA249',
#  'TAXA248',
#  'TAXA247',
#  'TAXA246',
#  'TAXA245',
#  'TAXA244',
#  'TAXA243',
#  'TAXA242',
#  'TAXA241',
#  'TAXA240',
#  'TAXA24',
#  'TAXA23L',
#  'TAXA239',
#  'TAXA238',
#  'TAXA237',
#  'TAXA236',
#  'TAXA235',
#  'TAXA234',
#  'TAXA233',
#  'TAXA232',
#  'TAXA231',
#  'TAXA230',
#  'TAXA23',
#  'TAXA22L',
#  'TAXA229',
#  'TAXA228',
#  'TAXA227',
#  'TAXA226',
#  'TAXA225',
#  'TAXA224',
#  'TAXA223',
#  'TAXA222',
#  'TAXA221',
#  'TAXA220',
#  ...]

# %%
acoes = []
for ticker in tickers:
    
    try:
        
        int(ticker[3]) #a quarta letra tem que ser uma string, não um número
        
    except:

        final_ticker = ticker[4:]

        if len(final_ticker) == 2:

            if final_ticker == "11":

                if (ticker[0:4] + "3") in acoes or (ticker[0:4] + "4") in acoes:

                    acoes.append(ticker)

        if len(final_ticker) == 1:  

            if final_ticker == "3" or final_ticker == "4":

                acoes.append(ticker)

# %%
acoes
# Out:
# ['ZAMP3',
#  'YDUQ3',
#  'YBRA4',
#  'YBRA3',
#  'WLMM4',
#  'WLMM3',
#  'WIZC3',
#  'WHRL4',
#  'WHRL3',
#  'WEST3',
#  'WEGE3',
#  'VVEO3',
#  'VULC3',
#  'VSTE3',
#  'VSPT4',
#  'VSPT3',
#  'VLID3',
#  'VIVT3',
#  'VIVR3',
#  'VIVA3',
#  'VITT3',
#  'VBBR3',
#  'VAMO3',
#  'VALE3',
#  'USIM3',
#  'UPKP3',
#  'UNIP3',
#  'UGPA3',
#  'UCAS3',
#  'TXRX4',
#  'TXRX3',
#  'TUPY3',
#  'TTEN3',
#  'TRPL4',
#  'TRPL3',
#  'TRIS3',
#  'TRAD3',
#  'TPIS3',
#  'TOTS3',
#  'TKNO4',
#  'TKNO3',
#  'TIMS3',
#  'TGMA3',
#  'TFCO4',
#  'TEND3',
#  'TELB4',
#  'TELB3',
#  'TEKA4',
#  'TEKA3',
#  'TEGA3',
#  'TECN3',
#  'TCSA3',
#  'TASA4',
#  'TASA3',
#  'TAEE4',
#  'TAEE3',
#  'TAEE11',
#  'SYNE3',
#  'SUZB3',
#  'STBP3',
#  'SRNA3',
#  'SOND3',
#  'SOMA3',
#  'SOJA3',
#  'SNSY3',
#  'SMTO3',
#  'SMFT3',
#  'SLCE3',
#  'SIMH3',
#  'SHUL4',
#  'SHUL3',
#  'SHOW3',
#  'SGPS3',
#  'SEQL3',
#  'SEER3',
#  'SCAR3',
#  'SBSP3',
#  'SBFG3',
#  'SAPR4',
#  'SAPR3',
#  'SAPR11',
#  'SANB4',
#  'SANB3',
#  'SANB11',
#  'SAEN3',
#  'RSUL4',
#  'RSUL3',
#  'RSID3',
#  'RRRP3',
#  'RPMG3',
#  'RPAD3',
#  'ROMI3',
#  'RNEW4',
#  'RNEW3',
#  'RNEW11',
#  'RENT3',
#  'REDE3',
#  'RECV3',
#  'RDOR3',
#  'RDNI3',
#  'RCSL4',
#  'RCSL3',
#  'RAPT4',
#  'RAPT3',
#  'RANI3',
#  'RAIZ4',
#  'RAIL3',
#  'RADL3',
#  'QVQP3',
#  'QUSW3',
#  'QUAL3',
#  'PTNT4',
#  'PTNT3',
#  'PTCA3',
#  'PTBL3',
#  'PSSA3',
#  'PRPT3',
#  'PRNR3',
#  'PRIO3',
#  'PPAR3',
#  'POSI3',
#  'PORT3',
#  'POMO4',
#  'POMO3',
#  'PNVL3',
#  'PMAM3',
#  'PLPL3',
#  'PLAS3',
#  'PINE4',
#  'PINE3',
#  'PINE11',
#  'PGMN3',
#  'PGMN11',
#  'PFRM3',
#  'PETZ3',
#  'PETR4',
#  'PETR3',
#  'PEAB4',
#  'PEAB3',
#  'PDTC3',
#  'PDGR3',
#  'PCAR3',
#  'PATI4',
#  'PATI3',
#  'PASS3',
#  'OSXB3',
#  'ORVR3',
#  'OPTS3',
#  'OPSE3',
#  'OPGM3',
#  'OPCT3',
#  'ONCO3',
#  'OIBR4',
#  'OIBR3',
#  'OFSA3',
#  'ODPV3',
#  'ODER4',
#  'ODER3',
#  'NUTR3',
#  'NTCO3',
#  'NRTQ3',
#  'NORD3',
#  'NINJ3',
#  'NGRD3',
#  'NEXP3',
#  'NEOE3',
#  'NEMO3',
#  'MYPK3',
#  'MWET4',
#  'MWET3',
#  'MULT3',
#  'MTSA4',
#  'MTSA3',
#  'MTRE3',
#  'MSRO3',
#  'MSPA4',
#  'MSPA3',
#  'MRVE3',
#  'MRFG3',
#  'MOVI3',
#  'MOAR3',
#  'MNZC3',
#  'MNPR3',
#  'MNDL3',
#  'MMAQ4',
#  'MMAQ3',
#  'MLAS3',
#  'MILS3',
#  'MGLU3',
#  'MGEL4',
#  'MGEL3',
#  'MERC4',
#  'MERC3',
#  'MELK3',
#  'MEAL3',
#  'MDNE3',
#  'MDIA3',
#  'MBLY3',
#  'MATD3',
#  'MAPT4',
#  'MAPT3',
#  'LWSA3',
#  'LVTC3',
#  'LUXM4',
#  'LUXM3',
#  'LUPA3',
#  'LUPA11',
#  'LREN3',
#  'LPSB3',
#  'LOGN3',
#  'LOGG3',
#  'LMED3',
#  'LLBI3',
#  'LJQQ3',
#  'LIPR3',
#  'LIGT3',
#  'LEVE3',
#  'LAVV3',
#  'LAND3',
#  'KRSA3',
#  'KLBN4',
#  'KLBN3',
#  'KLBN11',
#  'KLAS3',
#  'KEPL3',
#  'JSLG3',
#  'JOPA4',
#  'JOPA3',
#  'JHSF3',
#  'JFEN3',
#  'JBSS3',
#  'JALL3',
#  'ITUB4',
#  'ITUB3',
#  'ITSA4',
#  'ITSA3',
#  'IRBR3',
#  'INTB3',
#  'INNC3',
#  'INEP4',
#  'INEP3',
#  'IGTI4',
#  'IGTI3',
#  'IGTI11',
#  'IGSN3',
#  'IFCM3',
#  'IFCM11',
#  'HYPE3',
#  'HOOT4',
#  'HOOT3',
#  'HMOB3',
#  'HETA4',
#  'HETA3',
#  'HBTS3',
#  'HBSA3',
#  'HBRE3',
#  'HBOR3',
#  'HAPV3',
#  'HAGA4',
#  'HAGA3',
#  'GUAR3',
#  'GSHP3',
#  'GRND3',
#  'GRAO3',
#  'GPAR3',
#  'GOLL4',
#  'GOLL3',
#  'GOLL11',
#  'GOAU4',
#  'GOAU3',
#  'GMAT3',
#  'GGPS3',
#  'GGBR4',
#  'GGBR3',
#  'GFSA3',
#  'GFSA11',
#  'GEPA4',
#  'GEPA3',
#  'FRTA3',
#  'FRIO3',
#  'FRAS3',
#  'FLRY3',
#  'FIQE3',
#  'FIGE4',
#  'FIGE3',
#  'FIEI3',
#  'FHER3',
#  'FESA4',
#  'FESA3',
#  'EZTC3',
#  'EVEN3',
#  'EUFA3',
#  'EUCA4',
#  'EUCA3',
#  'ETER3',
#  'ESTR4',
#  'ESTR3',
#  'ESPA3',
#  'EQTL3',
#  'EQPA3',
#  'EPAR3',
#  'ENMT4',
#  'ENMT3',
#  'ENJU3',
#  'ENGI4',
#  'ENGI3',
#  'ENGI11',
#  'ENEV3',
#  'ENAT3',
#  'EMBR3',
#  'EMAE4',
#  'EMAE3',
#  'ELMD3',
#  'ELET3',
#  'EKTR4',
#  'EKTR3',
#  'EGIE3',
#  'EGGY3',
#  'ECOR3',
#  'EALT4',
#  'EALT3',
#  'DXCO3',
#  'DTCY4',
#  'DTCY3',
#  'DOTZ3',
#  'DOHL4',
#  'DOHL3',
#  'DMVF3',
#  'DMFN3',
#  'DIRR3',
#  'DEXP4',
#  'DEXP3',
#  'DESK3',
#  'DASA3',
#  'DASA11',
#  'CYRE3',
#  'CXSE3',
#  'CVCB3',
#  'CURY3',
#  'CTSA4',
#  'CTSA3',
#  'CTNM4',
#  'CTNM3',
#  'CTKA4',
#  'CTKA3',
#  'CTCA3',
#  'CSUD3',
#  'CSRN3',
#  'CSNA3',
#  'CSMG3',
#  'CSED3',
#  'CSAN3',
#  'CRTE3',
#  'CRPG3',
#  'CRIV4',
#  'CRIV3',
#  'CRFB3',
#  'CPLE3',
#  'CPFE3',
#  'CORR4',
#  'CORR3',
#  'COMR3',
#  'COGN3',
#  'COCE3',
#  'CMSA4',
#  'CMSA3',
#  'CMIN3',
#  'CMIG4',
#  'CMIG3',
#  'CLSC4',
#  'CLSC3',
#  'CLSA3',
#  'CIEL3',
#  'CGRA4',
#  'CGRA3',
#  'CGEE4',
#  'CGEE3',
#  'CGAS3',
#  'CEGR3',
#  'CEED4',
#  'CEED3',
#  'CEEB3',
#  'CEDO4',
#  'CEDO3',
#  'CEBR3',
#  'CEAB3',
#  'CCRO3',
#  'CBEE3',
#  'CBAV3',
#  'CATA4',
#  'CATA3',
#  'CASN4',
#  'CASN3',
#  'CASH3',
#  'CAML3',
#  'CAMB3',
#  'CALI3',
#  'CALI11',
#  'CABI3',
#  'BSLI4',
#  'BSLI3',
#  'BRSR3',
#  'BRQB3',
#  'BRKM3',
#  'BRIV4',
#  'BRIV3',
#  'BRIT3',
#  'BRGE3',
#  'BRGE11',
#  'BRFS3',
#  'BRAP4',
#  'BRAP3',
#  'BPAR3',
#  'BPAN4',
#  'BPAC3',
#  'BPAC11',
#  'BOBR4',
#  'BOBR3',
#  'BNBR3',
#  'BMOB3',
#  'BMKS3',
#  'BMIN4',
#  'BMIN3',
#  'BMGB4',
#  'BMEB4',
#  'BMEB3',
#  'BLAU3',
#  'BIOM3',
#  'BIOM11',
#  'BHIA3',
#  'BGIP4',
#  'BGIP3',
#  'BETP3',
#  'BEES4',
#  'BEES3',
#  'BEEF3',
#  'BDLL4',
#  'BDLL3',
#  'BBSE3',
#  'BBML3',
#  'BBDC4',
#  'BBDC3',
#  'BBAS3',
#  'BBAS11',
#  'BAZA3',
#  'BAUH4',
#  'BAUH3',
#  'BALM4',
#  'BALM3',
#  'BAHI3',
#  'B3SA3',
#  'AZUL4',
#  'AZEV4',
#  'AZEV3',
#  'AZEV11',
#  'AVLL3',
#  'AVLL11',
#  'AURE3',
#  'ATOM3',
#  'ATMP3',
#  'ASAI3',
#  'ARZZ3',
#  'ARML3',
#  'APTI4',
#  'APTI3',
#  'APER3',
#  'ANIM3',
#  'AMER3',
#  'AMBP3',
#  'AMAR3',
#  'ALUP4',
#  'ALUP3',
#  'ALUP11',
#  'ALPK3',
#  'ALPA4',
#  'ALPA3',
#  'ALOS3',
#  'ALLD3',
#  'AHEB3',
#  'AGXY3',
#  'AGRO3',
#  'AFLT3',
#  'AESO3',
#  'AESB3',
#  'AERI3',
#  'ABEV3',
#  'ABCB4',
#  'AALR3']

# %%
len(acoes)
# Out:
# 488

# %%
for acao in acoes:
    
    mt5.symbol_select(acao)

# %% [markdown]
# ### Pegando o retorno e o preço de uma ação ao vivo

# %%
while True:
    ticker = 'WEGE3'

    retorno = mt5.symbol_info(ticker).price_change
    fechamento = mt5.symbol_info(ticker).last

    print(retorno, fechamento)
    time.sleep(1)
# Out:
#   File "C:\Users\ronal\AppData\Local\Temp\ipykernel_13908\3480177586.py", line 2
#     ticker = 'WEGE3'
#     ^
# IndentationError: unexpected indent

# %%
ticker = 'WEGE3'

retorno = mt5.symbol_info(ticker).price_change
fechamento = mt5.symbol_info(ticker).last

print(retorno, fechamento)
# Out:
# 0.0904 33.2

# %% [markdown]
# ### Pegando o histórico de cotações

# %%
acao = 'WEGE3'
timezone = pytz.timezone("Brazil/West")
data_inicial = (datetime.datetime.now(tz = timezone) - datetime.timedelta(days= 1095))
data_final = datetime.datetime.now(tz = timezone)

# %%
cotacoes = mt5.copy_rates_range(acao, mt5.TIMEFRAME_D1, data_inicial, data_final)

cotacoes = pd.DataFrame(cotacoes)
cotacoes
# Out:
#            time   open   high    low  close  tick_volume  spread  real_volume
# 0    1611792000  42.39  42.70  41.55  42.13        24440       1     10061600
# 1    1611878400  41.90  42.32  40.02  40.13        24702       1     11440600
# 2    1612137600  40.91  41.14  39.95  40.49        28759       1     13618000
# 3    1612224000  41.19  41.83  40.42  40.71        29410       1     13317000
# 4    1612310400  41.19  42.47  40.75  42.47        23301       1     12521200
# ..          ...    ...    ...    ...    ...          ...     ...          ...
# 742  1705881600  33.49  33.66  33.20  33.38        11734       1      3767000
# 743  1705968000  33.51  33.81  33.39  33.77        17272       1      5512800
# 744  1706054400  33.95  33.95  33.36  33.47        15539       1      6881200
# 745  1706140800  33.48  33.61  33.21  33.25        10792       1      4835300
# 746  1706227200  33.40  33.50  33.04  33.17         5642       0      3828900
#
# [747 rows x 8 columns]

# %%
cotacoes = cotacoes[['time', 'open', 'high', 'low', 'close']]
cotacoes['time']=pd.to_datetime(cotacoes['time'], unit='s')
cotacoes['ticker'] = acao

cotacoes
# Out:
# C:\Users\ronal\AppData\Local\Temp\ipykernel_13908\1283511889.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cotacoes['time']=pd.to_datetime(cotacoes['time'], unit='s')
# C:\Users\ronal\AppData\Local\Temp\ipykernel_13908\1283511889.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cotacoes['ticker'] = acao
#           time   open   high    low  close ticker
# 0   2021-01-28  42.39  42.70  41.55  42.13  WEGE3
# 1   2021-01-29  41.90  42.32  40.02  40.13  WEGE3
# 2   2021-02-01  40.91  41.14  39.95  40.49  WEGE3
# 3   2021-02-02  41.19  41.83  40.42  40.71  WEGE3
# 4   2021-02-03  41.19  42.47  40.75  42.47  WEGE3
# ..         ...    ...    ...    ...    ...    ...
# 742 2024-01-22  33.49  33.66  33.20  33.38  WEGE3
# 743 2024-01-23  33.51  33.81  33.39  33.77  WEGE3
# 744 2024-01-24  33.95  33.95  33.36  33.47  WEGE3
# 745 2024-01-25  33.48  33.61  33.21  33.25  WEGE3
# 746 2024-01-26  33.40  33.50  33.04  33.17  WEGE3
#
# [747 rows x 6 columns]
